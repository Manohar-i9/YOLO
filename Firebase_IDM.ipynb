# %% [markdown]
# ## YOLO - Intruder Detection

# %% [markdown]
# ### Required Dependencies

# %%
# Supress warnings for entire notebook
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the video processing and deep learning modules
import cv2
import numpy as np
import os
import threading
from ultralytics import YOLO
from datetime import datetime
import time
import json

# %%
# # Get firebase backend storage functions
import firebase_admin
from firebase_admin import credentials, storage, firestore

# %% [markdown]
# ### YOLO - Setup

# %%
# Load YOLO model
yolo_model = YOLO("yolov8n.pt")  # Ensure you have the model downloaded

# %%
# Create a folder for saving intruder images
INTRUDER_FOLDER = "intruders"
os.makedirs(INTRUDER_FOLDER, exist_ok=True)

# %%
# Intruder detection state
state = 'stop'   # 'stop', 'start'
last_intruder_time = 0    # intruder time tracker
follow_update = False     # update flag to tick intruder time

# Flag to prevent multiple burst threads running at the same time
burst_in_progress = False

# %% [markdown]
# ### YOLO - Functions

# %%
# Function to detect people using YOLO
def detect_persons(frame):
    results = yolo_model(frame)  # Run YOLO
    persons = []

    for result in results:
        for box, class_id, conf in zip(result.boxes.xyxy, result.boxes.cls, result.boxes.conf):  # Extract confidence score
            if int(class_id) == 0:  # Class 0 in COCO is "person"
                x1, y1, x2, y2 = map(int, box[:4])
                persons.append({
                    "bbox": (x1, y1, x2, y2),  # Bounding box
                    "confidence": conf.item()   # Confidence score
                })

    return persons

# %%
# Helper function to save a frame
def save_intruder_frame(frame, prefix=""):
    # Save files to local disk
    filename = f"{INTRUDER_FOLDER}/Intruder_{prefix}_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.jpg"
    cv2.imwrite(filename, frame)
    print(f"Saved: {filename}")
    
    # Optional: Call FIREBASE cloud upload function here
    handle_intruder_detection(filename, confidence)

# %%
# First Burst Function - 5 photos immediately, 300ms apart
def first_burst(frame):
    global state, burst_in_progress
    
    if state != 'stop' or burst_in_progress:
        return  # Already capturing or burst in progress
    
    state = 'start'
    burst_in_progress = True  # Set the flag to indicate burst is in progress
    print("Intruder detected - Starting first burst capture")

    # Background thread for burst capture
    def capture_burst():
        global burst_in_progress
        
        for i in range(5):
            save_intruder_frame(frame, f"{i+1}_burst")
            time.sleep(0.3)  # This sleep only affects the burst thread, not the main loop

        burst_in_progress = False  # Reset flag after burst capture is complete

    # Start a thread for the burst capture
    threading.Thread(target=capture_burst, daemon=True).start()

# %%
# Follow-up Function - 1 photo every 2 seconds
def follow_up(frame):
    global state, last_intruder_time, follow_update
    
    if state != 'start':
        return  # No active capture
    
    if time.time() - last_intruder_time >= 2:  # 2 seconds interval
        save_intruder_frame(frame, "followup")
        last_intruder_time = time.time()

# %%
# Exit Function - stop after 5 seconds of no intruder detected
def exit_capture():
    print("... INSIDE EXIT...")
    global state, follow_update
    
    print("No intruder for 5 seconds - Stopping capture")
    state = 'stop'
    follow_update = False

# %% [markdown]
# ### Firebase - Functions

# %%
# # Upload image to Firebase Storage
def upload_image(image_path):
    bucket = storage.bucket()
    blob = bucket.blob(f"intruders/{os.path.basename(image_path)}")
    blob.upload_from_filename(image_path)
    blob.make_public()  # Makes the image URL publicly accessible (optional)

    return blob.public_url

# %%
# # Save Metadata to Firestore
def save_metadata(image_url, confidence):
    doc_ref = db.collection('intruder_logs').add({
        'imageUrl': image_url,
        'timestamp': datetime.now().isoformat(),
        'confidence': confidence
    })

# %%
# # Full Function to Call from Detection Code
def handle_intruder_detection(image_path, confidence):
    image_url = upload_image(image_path)
    save_metadata(image_url, confidence)
    print(f"Intruder saved: {image_url}")

# %% [markdown]
# ### Firebase - Setup

# %%
# # Initialize Firebase App
cred = credentials.Certificate("firebase_key.json")
firebase_admin.initialize_app(cred, {
    'storageBucket': 'intruder-detection-syste-3e8f1.firebasestorage.app'
})
db = firestore.client()

# %% [markdown]
# ### Intruder Detection Loop - Frame by Frame Analysis

# %%
# Initialize webcam
cap = cv2.VideoCapture(0)

# %%
# Start analyzing the frames until quit
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    persons = detect_persons(frame)
    
    if persons:  # Intruder Detected
#         print("PERSON DETECTED ...")
        if follow_update == False:
            last_intruder_time = time.time()
            follow_update = True

        if state == 'stop':
#             print("FIRST BURST ...")
            first_burst(frame)  # Trigger burst when intruder detected for first time
        
        # Draw boxes and labels
        for person in persons:
            x1, y1, x2, y2 = person["bbox"]
            confidence = person["confidence"]
 
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
            text = f"Intruder Detected: {confidence:.2f}"
            cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
        
        # Continuous follow-up capture if burst is done
        if state == 'start' and burst_in_progress == False:
            follow_up(frame)

    else:  # No intruder detected
        if state == 'start' and time.time() - last_intruder_time > 5:
            exit_capture()
    
    # Display the live feed with annotations
    cv2.imshow("Intruder Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 persons, 1 knife, 245.8ms
# Speed: 9.2ms preprocess, 245.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Intruder detected - Starting first burst capture
# Saved: intruders/Intruder_1_burst_2025-03-22_21-32-51.jpg
#
# 0: 480x640 2 persons, 112.6ms
# Speed: 7.2ms preprocess, 112.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.2ms
# Speed: 3.9ms preprocess, 120.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 109.4ms
# Speed: 3.2ms preprocess, 109.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 103.4ms
# Speed: 3.5ms preprocess, 103.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 99.7ms
# Speed: 2.5ms preprocess, 99.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 104.3ms
# Speed: 2.4ms preprocess, 104.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.9ms
# Speed: 1.9ms preprocess, 118.9ms inference, 15.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 100.0ms
# Speed: 3.9ms preprocess, 100.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 100.3ms
# Speed: 2.9ms preprocess, 100.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_1_burst_2025-03-22_21-32-51.jpg
# 0: 480x640 2 persons, 93.2ms
# Speed: 1.9ms preprocess, 93.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 88.6ms
# Speed: 2.5ms preprocess, 88.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 89.5ms
# Speed: 2.4ms preprocess, 89.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Saved: intruders/Intruder_2_burst_2025-03-22_21-32-52.jpg
# 0: 480x640 2 persons, 90.5ms
# Speed: 2.5ms preprocess, 90.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 82.4ms
# Speed: 2.2ms preprocess, 82.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 92.7ms
# Speed: 2.3ms preprocess, 92.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.7ms
# Speed: 2.0ms preprocess, 80.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 94.1ms
# Speed: 3.4ms preprocess, 94.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_2_burst_2025-03-22_21-32-52.jpg
# 0: 480x640 2 persons, 99.9ms
# Speed: 2.4ms preprocess, 99.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 78.2ms
# Speed: 2.1ms preprocess, 78.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 88.3ms
# Speed: 2.5ms preprocess, 88.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Saved: intruders/Intruder_3_burst_2025-03-22_21-32-53.jpg
# 0: 480x640 2 persons, 85.1ms
# Speed: 2.6ms preprocess, 85.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 102.2ms
# Speed: 3.7ms preprocess, 102.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 79.3ms
# Speed: 2.5ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 89.6ms
# Speed: 2.3ms preprocess, 89.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 79.2ms
# Speed: 2.6ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_3_burst_2025-03-22_21-32-53.jpg
# 0: 480x640 2 persons, 96.1ms
# Speed: 2.3ms preprocess, 96.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 86
1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 dog, 109.3ms
# Speed: 2.1ms preprocess, 109.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 1 dog, 112.1ms
# Speed: 2.0ms preprocess, 112.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 dog, 107.9ms
# Speed: 2.4ms preprocess, 107.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cats, 119.5ms
# Speed: 3.2ms preprocess, 119.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 132.7ms
# Speed: 2.8ms preprocess, 132.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 112.7ms
# Speed: 2.1ms preprocess, 112.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 120.0ms
# Speed: 2.3ms preprocess, 120.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.8ms
# Speed: 3.3ms preprocess, 122.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 114.2ms
# Speed: 2.5ms preprocess, 114.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 114.1ms
# Speed: 2.7ms preprocess, 114.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 128.8ms
# Speed: 2.8ms preprocess, 128.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 119.7ms
# Speed: 3.7ms preprocess, 119.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Saved: intruders/Intruder_followup_2025-03-22_21-33-17.jpg
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_followup_2025-03-22_21-33-17.jpg
#
# 0: 480x640 1 person, 207.3ms
# Speed: 8.3ms preprocess, 207.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 dog, 136.8ms
# Speed: 2.9ms preprocess, 136.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 123.8ms
# Speed: 4.1ms preprocess, 123.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.3ms
# Speed: 2.6ms preprocess, 122.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 117.0ms
# Speed: 2.5ms preprocess, 117.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 133.7ms
# Speed: 3.7ms preprocess, 133.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 96.8ms
# Speed: 1.9ms preprocess, 96.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 130.8ms
# Speed: 2.4ms preprocess, 130.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 2 persons, 129.6ms
# Speed: 2.5ms preprocess, 129.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 134.0ms
# Speed: 3.3ms preprocess, 134.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 141.1ms
# Speed: 3.1ms preprocess, 141.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 dog, 136.2ms
# Speed: 3.1ms preprocess, 136.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 128.3ms
# Speed: 3.0ms preprocess, 128.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.8ms
# Speed: 2.4ms preprocess, 123.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Saved: intruders/Intruder_followup_2025-03-22_21-33-20.jpg
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_followup_2025-03-22_21-33-20.jpg
#
# 0: 480x640 2 persons, 1 cat, 212.8ms
# Speed: 7.4ms preprocess, 212.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 127.3ms
# Speed: 2.8ms preprocess, 127.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 114.9ms
# Speed: 3.3ms preprocess, 114.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 114.2ms
# Speed: 3.4ms preprocess, 114.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 112.0ms
# Speed: 3.6ms preprocess, 112.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 106.3ms
# Speed: 2.9ms preprocess, 106.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 83.5ms
# Speed: 2.4ms preprocess, 83.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 112.8ms
# Speed: 2.8ms preprocess, 112.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 1 teddy bear, 140.5ms
# Speed: 2.9ms preprocess, 140.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 109.6ms
# Speed: 2.2ms preprocess, 109.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.8ms
# Speed: 2.6ms preprocess, 121.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 132.7ms
# Speed: 2.4ms preprocess, 132.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.6ms
# Speed: 3.0ms preprocess, 129.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.3ms
# Speed: 2.6ms preprocess, 121.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cat, 128.3ms
# Speed: 2.4ms preprocess, 128.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Saved: intruders/Intruder_followup_2025-03-22_21-33-23.jpg
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_followup_2025-03-22_21-33-23.jpg
#
# 0: 480x640 2 persons, 197.5ms
# Speed: 6.3ms preprocess, 197.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 111.5ms
# Speed: 2.9ms preprocess, 111.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 128.8ms
# Speed: 2.3ms preprocess, 128.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.0ms
# Speed: 2.4ms preprocess, 120.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 148.7ms
# Speed: 3.2ms preprocess, 148.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 114.1ms
# Speed: 2.1ms preprocess, 114.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 137.8ms
# Speed: 3.2ms preprocess, 137.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 112.9ms
# Speed: 3.4ms preprocess, 112.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 100.4ms
# Speed: 2.5ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 85.2ms
# Speed: 1.6ms preprocess, 85.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 108.3ms
# Speed: 2.2ms preprocess, 108.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 99.4ms
# Speed: 2.2ms preprocess, 99.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.7ms
# Speed: 2.2ms preprocess, 119.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 dog, 102.6ms
# Speed: 2.8ms preprocess, 102.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 116.0ms
# Speed: 2.5ms preprocess, 116.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Saved: intruders/Intruder_followup_2025-03-22_21-33-25.jpg
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_followup_2025-03-22_21-33-25.jpg
#
# 0: 480x640 2 persons, 198.8ms
# Speed: 9.8ms preprocess, 198.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons,
3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 102.9ms
# Speed: 2.5ms preprocess, 102.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 129.2ms
# Speed: 2.6ms preprocess, 129.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 116.9ms
# Speed: 2.1ms preprocess, 116.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 128.3ms
# Speed: 3.8ms preprocess, 128.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 116.9ms
# Speed: 2.6ms preprocess, 116.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 104.4ms
# Speed: 3.4ms preprocess, 104.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Saved: intruders/Intruder_followup_2025-03-22_21-33-49.jpg
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_followup_2025-03-22_21-33-49.jpg
#
# 0: 480x640 2 persons, 206.1ms
# Speed: 5.2ms preprocess, 206.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 133.8ms
# Speed: 2.1ms preprocess, 133.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 116.0ms
# Speed: 2.2ms preprocess, 116.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 129.7ms
# Speed: 2.9ms preprocess, 129.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.7ms
# Speed: 2.3ms preprocess, 118.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.1ms
# Speed: 2.4ms preprocess, 119.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.6ms
# Speed: 3.3ms preprocess, 129.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 2 persons, 124.6ms
# Speed: 2.9ms preprocess, 124.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.7ms
# Speed: 3.1ms preprocess, 124.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.6ms
# Speed: 4.0ms preprocess, 129.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 131.1ms
# Speed: 2.2ms preprocess, 131.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 113.7ms
# Speed: 3.0ms preprocess, 113.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.5ms
# Speed: 2.8ms preprocess, 121.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Saved: intruders/Intruder_followup_2025-03-22_21-33-51.jpg
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_followup_2025-03-22_21-33-51.jpg
#
# 0: 480x640 2 persons, 1 knife, 156.7ms
# Speed: 16.2ms preprocess, 156.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 105.6ms
# Speed: 3.4ms preprocess, 105.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 103.4ms
# Speed: 2.2ms preprocess, 103.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 110.2ms
# Speed: 3.6ms preprocess, 110.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.9ms
# Speed: 2.5ms preprocess, 121.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.4ms
# Speed: 2.1ms preprocess, 119.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 125.3ms
# Speed: 2.1ms preprocess, 125.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.8ms
# Speed: 3.1ms preprocess, 165.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 111.2ms
# Speed: 3.6ms preprocess, 111.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 111.3ms
# Speed: 3.7ms preprocess, 111.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 104.3ms
# Speed: 2.5ms preprocess, 104.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 107.2ms
# Speed: 2.0ms preprocess, 107.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 133.2ms
# Speed: 2.1ms preprocess, 133.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.8ms
# Speed: 2.2ms preprocess, 119.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Saved: intruders/Intruder_followup_2025-03-22_21-33-54.jpg
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_followup_2025-03-22_21-33-54.jpg
#
# 0: 480x640 2 persons, 204.3ms
# Speed: 3.8ms preprocess, 204.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.0ms
# Speed: 2.2ms preprocess, 125.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 116.7ms
# Speed: 2.2ms preprocess, 116.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 100.2ms
# Speed: 2.1ms preprocess, 100.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.8ms
# Speed: 2.8ms preprocess, 117.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.6ms
# Speed: 2.5ms preprocess, 129.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 127.8ms
# Speed: 2.6ms preprocess, 127.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 102.3ms
# Speed: 2.2ms preprocess, 102.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 113.4ms
# Speed: 2.0ms preprocess, 113.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.7ms
# Speed: 1.8ms preprocess, 123.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 100.3ms
# Speed: 2.5ms preprocess, 100.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.9ms
# Speed: 2.8ms preprocess, 119.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.3ms
# Speed: 3.8ms preprocess, 122.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.9ms
# Speed: 3.5ms preprocess, 123.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Saved: intruders/Intruder_followup_2025-03-22_21-33-57.jpg
# Intruder saved: https://storage.googleapis.com/intruder-detection-syste-3e8f1.firebasestorage.app/intruders/Intruder_followup_2025-03-22_21-33-57.jpg
#
# 0: 480x640 3 persons, 209.6ms
# Speed: 4.6ms preprocess, 209.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.0ms
# Speed: 2.5ms preprocess, 121.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 95.7ms
# Speed: 2.5ms preprocess, 95.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 106.3ms
# Speed: 2.1ms preprocess, 106.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 90.0ms
# Speed: 2.5ms preprocess, 90.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 79.2ms
# Speed: 1.9ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.6ms
# Speed: 2.4ms preprocess, 84.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 89.3ms
# Speed: 2.5ms preprocess, 89.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
